# %%
import os

os.chdir("../")

from tests.test_utils import generate_mock_data

# %%
generate_mock_data()
# Out:
#     id                                               name  \
# 0  NaN  【中古】リーバイス Levi's 70s 501 66前期 BIG EビッグE デニムパンツ...
# 1  NaN  【中古】Lee｜リー デニム ジャケット 101-J 50年代後期 ヴィンテージ ブルー サ...
# 2  NaN  【中古】Levi’s◆70s/ベルボトム/ボタン裏39/ブーツカットパンツ/IDG/646-...
# 3  NaN  古着 00'S パタゴニア Patagonia ORGANIC COTTON オーガニックコ...
# 4  NaN  【中古】Levi’s◆60s/4th/トラッカージャケット/BIGE/ボタン裏52/Gジャン...
# 5  NaN  【中古】コンバース CONVERSE CANVAS ALL STAR HI キャンバスオール...
# 6  NaN  古着 90'S チャンピオン Champion REVERSE WEAVE リバースウィーブ...
# 7  NaN  【中古】Levi’s◆70s/501/66BigE/足長/ボタン裏6/シングル/赤耳/デニム...
# 8  NaN        【中古】Levi’s◆501/66後期/チェーンステッチ/IDG///【メンズウェア】
# 9  NaN        【中古】Levi’s◆550/カットオフ/ボトム/34/ブラックデニム【メンズウェア】
# 10 NaN  90s USA製 ヴィンテージ リーバイス Levi's スタプレ 517 スラックス フレ...
# 11 NaN  【中古】未使用品 リー LEE 44J カバーオール ロコジャケット LM5412-924 ...
# 12 NaN  Levi's リーバイス 70s 501 66前期 BigE 両面BigE 刻印6 フライボ...
# 13 NaN  【中古】リーバイス Levis 501 ORIGINAL SELVEDGE DENIM メン...
# 14 NaN  【中古】Levi’s◆ストレートパンツ/--/デニム/BLU/40505-0209【メンズウェア】
# ...
